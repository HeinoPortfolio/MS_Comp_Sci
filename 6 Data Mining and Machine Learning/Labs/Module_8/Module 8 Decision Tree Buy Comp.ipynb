# %% [markdown]
# # Module 8 Decision Tree
#
# - uses **cs654_computers.csv**
#
# - "D:\Jupyter_Notebooks\CS654ML_DM\Data\cs654_computers.csv"

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ### Load the training data; same as presented in one of our class slides.
#
# **Attributes:**
#
# - Age attribute: <=30 as  1, 31..40 as 2, > 40 as 3
# - Income attribute: low as 1, medium as 2, high as 3
# - Student attribute: yes as 1, no as 2
# - Credit attribute: fair as 1, excellent as 2
# - Buy computer attribute: Yes as 1, No as 0

# %%
df = pd.read_csv("D:\\Jupyter_Notebooks\\CS654ML_DM\\Data\\cs654_computers.csv")

df
# Out:
#     age  income  student  credit  buy
# 0     1       3        2       1    0
# 1     1       3        2       2    0
# 2     2       3        2       1    1
# 3     3       2        2       1    1
# 4     3       1        1       1    1
# 5     3       1        1       2    0
# 6     2       1        1       2    1
# 7     1       2        2       1    0
# 8     1       1        1       1    1
# 9     3       2        1       1    1
# 10    1       2        1       2    1
# 11    2       2        2       2    1
# 12    2       3        1       1    1
# 13    3       2        2       2    0

# %% [markdown]
# ### Use the first 4 attributes as training data

# %%
X = df[['age', 'income', 'student', 'credit']].to_numpy()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 X = df[['age', 'income', 'students', 'credit']].to_numpy()
#
# File ~\anaconda3\envs\Tensorflow\lib\site-packages\pandas\core\frame.py:4108, in DataFrame.__getitem__(self, key)
#    4106     if is_iterator(key):
#    4107         key = list(key)
# -> 4108     indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    4110 # take() does not accept boolean indexers
#    4111 if getattr(indexer, "dtype", None) == bool:
#
# File ~\anaconda3\envs\Tensorflow\lib\site-packages\pandas\core\indexes\base.py:6200, in Index._get_indexer_strict(self, key, axis_name)
#    6197 else:
#    6198     keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
# -> 6200 self._raise_if_missing(keyarr, indexer, axis_name)
#    6202 keyarr = self.take(indexer)
#    6203 if isinstance(key, Index):
# ...

# %% [markdown]
# ### Class labels for training data

# %%
#y = df['buy'].to_numpy()

# %%
# Train the decision tree; construct the decision tree; learn the decision tree

# %%
from sklearn import tree

#clf = tree.DecisionTreeClassifier()
#clf = clf.fit(X, y)

# %% [markdown]
# ### This is the new customer that we are going to predict a potential computer purchase.
#  - age <= 30
#  - income = medium
#  - student = yes
#  - credit_rating = fair
#
# thus, 1, 2, 1, 1

# %%
#new_customer = [1, 2, 1, 1]

# %% [markdown]
# ### Predict if the new customer is going to buy a new computer: 1:Yes, 0:No.

# %%
# clf.predict([np.array(new_customer)])

# %% [markdown]
# ### Predict the training data

# %%
clf.predict(X)

# %% [markdown]
# ### True labels of training data

# %%
y
