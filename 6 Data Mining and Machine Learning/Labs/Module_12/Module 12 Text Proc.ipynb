# %% [markdown]
# # Module 12 Text Processing
#
# - Demo shows basic text processing tasks.
# - Normalization
# - Stemming
# - Lemmatization
# - String Methods

# %% [markdown]
# ### Create a text sample.

# %%
s = "Text mining is a subfield of data mining. It also uses machine learning algorithms."

# %%
# import the sentence tokenizer.
from nltk.tokenize import sent_tokenize
import nltk

# %%
#nltk.download('punkt_tab')

# %% [markdown]
# ### A list of two sentences were returned.

# %%
# A list of two sentences were returned.
sent_tokenize(s)
# Out:
# ['Text mining is a subfield of data mining.',
#  'It also uses machine learning algorithms.']

# %% [markdown]
# ### Import the word tokenizer.

# %%
from nltk.tokenize import word_tokenize

# %% [markdown]
# ### Apply word tokenizer on one sentence.

# %%
word_tokenize("Text mining is a subfield of data mining.")
# Out:
# ['Text', 'mining', 'is', 'a', 'subfield', 'of', 'data', 'mining', '.']

# %%
import string

# %% [markdown]
# ### Show punctuation marks.

# %%
string.punctuation
# Out:
# '!"#$%&\'()*+,-./:;<=>?@[\\]^_`{|}~'

# %% [markdown]
# ### Add more marks if needed.

# %%
string.punctuation+'p'
# Out:
# '!"#$%&\'()*+,-./:;<=>?@[\\]^_`{|}~p'

# %%
string.punctuation
# Out:
# '!"#$%&\'()*+,-./:;<=>?@[\\]^_`{|}~'

# %%
len('!"#$%&\'()*+,-./:;<=>?@[\\]^_`{|}~')
# Out:
# 32

# %% [markdown]
# ### Remove punctuation.

# %%
s = "Text mining is a subfield of data mining."

s.translate(str.maketrans('','', string.punctuation))
# Out:
# 'Text mining is a subfield of data mining'

# %%
s = 'Text mining is a subfield of data mining'

# %% [markdown]
# ### split() is often used to filter each individual word.

# %%
s.split()
# Out:
# ['Text', 'mining', 'is', 'a', 'subfield', 'of', 'data', 'mining']

# %% [markdown]
# ### join() is used to create a combination of words.

# %%
l = ['love', 'text', 'mining']

" ".join(l)
# Out:
# 'love text mining'

# %% [markdown]
# ### nltk has a stopwords list.

# %%
from nltk.corpus import stopwords

english_stops = set(stopwords.words('english'))

# %%
english_stops
# Out:
# {'a',
#  'about',
#  'above',
#  'after',
#  'again',
#  'against',
#  'ain',
#  'all',
#  'am',
#  'an',
#  'and',
#  'any',
#  'are',
#  'aren',
#  "aren't",
#  'as',
#  'at',
#  'be',
#  'because',
#  'been',
#  'before',
#  'being',
#  'below',
#  'between',
#  'both',
#  'but',
#  'by',
#  'can',
#  'couldn',
#  "couldn't",
#  'd',
#  'did',
#  'didn',
#  "didn't",
#  'do',
#  'does',
#  'doesn',
#  "doesn't",
#  'doing',
#  'don',
#  "don't",
#  'down',
#  'during',
#  'each',
#  'few',
#  'for',
#  'from',
#  'further',
#  'had',
#  'hadn',
#  "hadn't",
#  'has',
#  'hasn',
#  "hasn't",
#  'have',
#  'haven',
#  "haven't",
#  'having',
#  'he',
#  'her',
#  'here',
#  'hers',
#  'herself',
#  'him',
#  'himself',
#  'his',
#  'how',
#  'i',
#  'if',
#  'in',
#  'into',
#  'is',
#  'isn',
#  "isn't",
#  'it',
#  "it's",
#  'its',
#  'itself',
#  'just',
#  'll',
#  'm',
#  'ma',
#  'me',
#  'mightn',
#  "mightn't",
#  'more',
#  'most',
#  'mustn',
#  "mustn't",
#  'my',
#  'myself',
#  'needn',
#  "needn't",
#  'no',
#  'nor',
#  'not',
#  'now',
#  'o',
#  'of',
#  'off',
#  'on',
#  'once',
#  'only',
#  'or',
#  'other',
#  'our',
#  'ours',
#  'ourselves',
#  'out',
#  'over',
#  'own',
#  're',
#  's',
#  'same',
#  'shan',
#  "shan't",
#  'she',
#  "she's",
#  'should',
#  "should've",
#  'shouldn',
#  "shouldn't",
#  'so',
#  'some',
#  'such',
#  't',
#  'than',
#  'that',
#  "that'll",
#  'the',
#  'their',
#  'theirs',
#  'them',
#  'themselves',
#  'then',
#  'there',
#  'these',
#  'they',
#  'this',
#  'those',
#  'through',
#  'to',
#  'too',
#  'under',
#  'until',
#  'up',
#  've',
#  'very',
#  'was',
#  'wasn',
#  "wasn't",
#  'we',
#  'were',
#  'weren',
#  "weren't",
#  'what',
#  'when',
#  'where',
#  'which',
#  'while',
#  'who',
#  'whom',
#  'why',
#  'will',
#  'with',
#  'won',
#  "won't",
#  'wouldn',
#  "wouldn't",
#  'y',
#  'you',
#  "you'd",
#  "you'll",
#  "you're",
#  "you've",
#  'your',
#  'yours',
#  'yourself',
#  'yourselves'}

# %%
len(english_stops)
# Out:
# 179

# %%
print(english_stops)
# Out:
# {'is', 'was', 'from', 'on', 'then', 'their', 'her', 'he', 'both', 'of', 'themselves', 'if', "shouldn't", 'my', "don't", 'over', 'ma', 'here', "that'll", 'for', 'are', 'while', 'aren', 'as', 'your', 'have', 'at', "aren't", 'hers', 'own', "couldn't", 'hadn', 'these', 'why', 'm', 'same', "hasn't", 'an', 'not', "you'd", 'doing', 'yours', 'himself', 'ourselves', 'me', 'most', 'had', 'between', "doesn't", 'nor', 'further', 'shouldn', 'until', 'against', 'it', 'we', 'haven', "shan't", 'up', 'again', 'out', 'a', 'itself', 'them', "it's", 'than', 'won', 've', 'myself', 'how', "isn't", 'shan', 'no', 'when', 'didn', 'our', 'that', 'yourself', 'y', "you'll", 'whom', 'has', 'the', "you've", 'did', 'should', 'once', 'having', 'll', "needn't", "wouldn't", "she's", 'been', 'they', 'more', 'isn', 't', 'with', "didn't", "should've", 'yourselves', 'herself', 'does', 'couldn', 'off', 'being', 'all', 'by', 'were', 'or', 'can', "hadn't", 'am', 'below', 'weren', "you're", 'be', 're', 'some', 'which', "weren't", 'wasn', 'above', 'other', 'each', 'd', 'she', 'what', 'there', 'mustn', "wasn't", 'will', 'him', "mightn't", 'those', 'about', 'down', 'where', 'after', 'who', 'doesn', "haven't", 'just', 'only', 'to', 'you', 'few', 'hasn', 'into', 'because', "won't", 'o', 'so', 'mightn', 'wouldn', 'too', 'ain', 'through', 'in', 'during', 'needn', 'don', 'now', 'this', 'any', 'i', 'before', 'do', 'his', 's', 'under', 'ours', "mustn't", 'theirs', 'very', 'but', 'such', 'and', 'its'}

# %% [markdown]
# ## Stemming

# %% [markdown]
# ### Create a list of various forms of kick.

# %%
tokens = ['kick', 'kicks', 'kicked', 'kicking']

# %% [markdown]
# ### Load the nltk porter stemmer.

# %%
import nltk

porter = nltk.PorterStemmer()

# %%
for w in tokens:
    print(porter.stem(w))
# Out:
# kick
# kick
# kick
# kick

# %% [markdown]
# ## Lemmatization

# %% [markdown]
# ### Load the nltk WordNet lemmatizer

# %%
wnl = nltk.WordNetLemmatizer()

# %%
print(tokens)
# Out:
# ['kick', 'kicks', 'kicked', 'kicking']

# %%
for w in tokens:
    print(wnl.lemmatize(w))
# Out:
# kick
# kick
# kicked
# kicking

# %% [markdown]
# ## Normalization

# %%
s = 'Hello'
print(s.lower())
# Out:
# hello

# %%
s = 'hello'
print(s.upper())
# Out:
# HELLO

# %%
s = 'hello'
print(s.capitalize())
# Out:
# Hello

# %%
s = 'hello world'
print(s.title())
# Out:
# Hello World

# %% [markdown]
# ## Useful string methods

# %%
s = 'Sun'
print(s.isalpha())
# Out:
# True
