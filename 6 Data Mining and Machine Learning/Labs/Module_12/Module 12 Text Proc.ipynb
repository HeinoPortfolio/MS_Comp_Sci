# %% [markdown]
# # Module 12 Text Processing
#
# - Demo shows basic text processing tasks.
# - Normalization
# - Stemming
# - Lemmatization
# - String Methods

# %% [markdown]
# ### Create a text sample.

# %%
s = "Text mining is a subfield of data mining. It also uses machine learning algorithms."

# %%
from nltk.tokenize import sent_tokenize
import nltk

# %%
#nltk.download('punkt_tab')

# %% [markdown]
# ### A list of two sentences were returned.

# %%
sent_tokenize(s)
# Out:
# ['Text mining is a subfield of data mining.',
#  'It also uses machine learning algorithms.']

# %% [markdown]
# ### Import the word tokenizer.

# %%
from nltk.tokenize import word_tokenize

# %% [markdown]
# ### Apply word tokenizer on one sentence.

# %%
word_tokenize("Text mining is a subfield of data mining.")
# Out:
# ['Text', 'mining', 'is', 'a', 'subfield', 'of', 'data', 'mining', '.']

# %%
import string

# %% [markdown]
# ### Show punctuation marks.

# %%
string.punctuation
# Out:
# '!"#$%&\'()*+,-./:;<=>?@[\\]^_`{|}~'

# %% [markdown]
# ### Add more marks if needed.

# %%
string.punctuation+'p'
# Out:
# '!"#$%&\'()*+,-./:;<=>?@[\\]^_`{|}~p'

# %%
string.punctuation
# Out:
# '!"#$%&\'()*+,-./:;<=>?@[\\]^_`{|}~'

# %%
len('!"#$%&\'()*+,-./:;<=>?@[\\]^_`{|}~')
# Out:
# 32

# %% [markdown]
# ### Remove punctuation.

# %%
s = "Text mining is a subfield of data mining."

s.translate(str.maketrans('','', string.punctuation))
# Out:
# 'Text mining is a subfield of data mining'

# %%
s1 ='I love this, that, and all of those!'

# %%
s1.translate(str.maketrans('','', string.punctuation))
# Out:
# 'I love this that and all of those'

# %%
s = 'Text mining is a subfield of data mining.'

# %% [markdown]
# ### split() is often used to filter each individual word.

# %%
s.split()
# Out:
# ['Text', 'mining', 'is', 'a', 'subfield', 'of', 'data', 'mining.']

# %% [markdown]
# ### join() is used to create a combination of words.

# %%
l = ['I','love', 'text', 'mining']

" ".join(l)
# Out:
# 'I love text mining'

# %%
result =  " ".join(l)

# %%
result + "."
# Out:
# 'I love text mining.'

# %% [markdown]
# ### nltk has a stopwords list.

# %%
from nltk.corpus import stopwords

english_stops = list(set(stopwords.words('english')))

# %%
english_stops
# Out:
# ['with',
#  'too',
#  'above',
#  'weren',
#  'from',
#  'both',
#  'if',
#  'below',
#  'shouldn',
#  'were',
#  'him',
#  "couldn't",
#  'over',
#  'up',
#  'haven',
#  "hadn't",
#  'd',
#  'will',
#  'ain',
#  'into',
#  'can',
#  'll',
#  'that',
#  'same',
#  'down',
#  'to',
#  'aren',
#  'ma',
#  'on',
#  'who',
#  'during',
#  "mightn't",
#  "wouldn't",
#  'herself',
#  'after',
#  'very',
#  "she's",
#  'been',
#  'have',
#  'such',
#  'did',
#  'your',
#  'in',
#  'she',
#  'our',
#  'i',
#  'we',
#  't',
#  'here',
#  'any',
#  'my',
#  'hers',
#  'before',
#  'was',
#  "shan't",
#  'the',
#  'didn',
#  'ours',
#  'o',
#  "doesn't",
#  'do',
#  'wasn',
#  'be',
#  'until',
#  "won't",
#  'had',
#  'you',
#  'is',
#  "you'll",
#  'how',
#  'for',
#  'more',
#  'through',
#  "it's",
#  "shouldn't",
#  'it',
#  'only',
#  'he',
#  'won',
#  'or',
#  'has',
#  'while',
#  'further',
#  'by',
#  "isn't",
#  "you'd",
#  'couldn',
#  'does',
#  'himself',
#  'about',
#  'those',
#  'don',
#  "should've",
#  'themselves',
#  'of',
#  "you've",
#  "aren't",
#  'against',
#  'not',
#  'are',
#  'doing',
#  'these',
#  'few',
#  'should',
#  'just',
#  "needn't",
#  'its',
#  'there',
#  'hadn',
#  'being',
#  's',
#  'yours',
#  'wouldn',
#  'where',
#  'a',
#  'm',
#  'theirs',
#  'own',
#  'their',
#  'mustn',
#  'me',
#  'off',
#  'yourselves',
#  'itself',
#  'now',
#  'other',
#  "didn't",
#  'as',
#  'under',
#  'y',
#  'when',
#  'ourselves',
#  'isn',
#  'between',
#  "weren't",
#  'having',
#  'this',
#  'them',
#  'they',
#  'hasn',
#  'because',
#  "you're",
#  'what',
#  "that'll",
#  'some',
#  'so',
#  'myself',
#  'at',
#  "don't",
#  'once',
#  'needn',
#  'am',
#  "haven't",
#  'her',
#  'out',
#  'why',
#  'than',
#  'but',
#  'no',
#  'each',
#  've',
#  'nor',
#  'all',
#  'shan',
#  'again',
#  "hasn't",
#  'his',
#  "wasn't",
#  'then',
#  'most',
#  'and',
#  'which',
#  'yourself',
#  "mustn't",
#  're',
#  'whom',
#  'an',
#  'mightn',
#  'doesn']

# %%
english_stops[:10]
# Out:
# ['with',
#  'too',
#  'above',
#  'weren',
#  'from',
#  'both',
#  'if',
#  'below',
#  'shouldn',
#  'were']

# %%
len(english_stops)
# Out:
# 179

# %%
print(english_stops)
# Out:
# ['with', 'too', 'above', 'weren', 'from', 'both', 'if', 'below', 'shouldn', 'were', 'him', "couldn't", 'over', 'up', 'haven', "hadn't", 'd', 'will', 'ain', 'into', 'can', 'll', 'that', 'same', 'down', 'to', 'aren', 'ma', 'on', 'who', 'during', "mightn't", "wouldn't", 'herself', 'after', 'very', "she's", 'been', 'have', 'such', 'did', 'your', 'in', 'she', 'our', 'i', 'we', 't', 'here', 'any', 'my', 'hers', 'before', 'was', "shan't", 'the', 'didn', 'ours', 'o', "doesn't", 'do', 'wasn', 'be', 'until', "won't", 'had', 'you', 'is', "you'll", 'how', 'for', 'more', 'through', "it's", "shouldn't", 'it', 'only', 'he', 'won', 'or', 'has', 'while', 'further', 'by', "isn't", "you'd", 'couldn', 'does', 'himself', 'about', 'those', 'don', "should've", 'themselves', 'of', "you've", "aren't", 'against', 'not', 'are', 'doing', 'these', 'few', 'should', 'just', "needn't", 'its', 'there', 'hadn', 'being', 's', 'yours', 'wouldn', 'where', 'a', 'm', 'theirs', 'own', 'their', 'mustn', 'me', 'off', 'yourselves', 'itself', 'now', 'other', "didn't", 'as', 'under', 'y', 'when', 'ourselves', 'isn', 'between', "weren't", 'having', 'this', 'them', 'they', 'hasn', 'because', "you're", 'what', "that'll", 'some', 'so', 'myself', 'at', "don't", 'once', 'needn', 'am', "haven't", 'her', 'out', 'why', 'than', 'but', 'no', 'each', 've', 'nor', 'all', 'shan', 'again', "hasn't", 'his', "wasn't", 'then', 'most', 'and', 'which', 'yourself', "mustn't", 're', 'whom', 'an', 'mightn', 'doesn']

# %% [markdown]
# ## Stemming

# %% [markdown]
# ### Create a list of various forms of kick.

# %%
tokens = ['kick', 'kicks', 'kicked', 'kicking']

# %% [markdown]
# ### Load the nltk porter stemmer.

# %%
import nltk

porter = nltk.PorterStemmer()

# %%
for w in tokens:
    print(porter.stem(w))
# Out:
# kick
# kick
# kick
# kick

# %% [markdown]
# ## Lemmatization

# %% [markdown]
# ### Load the nltk WordNet lemmatizer

# %%
wnl = nltk.WordNetLemmatizer()

# %%
print(tokens)
# Out:
# ['kick', 'kicks', 'kicked', 'kicking']

# %%
for w in tokens:
    print(wnl.lemmatize(w))
# Out:
# kick
# kick
# kicked
# kicking

# %% [markdown]
# ## Normalization

# %%
s = 'Hello'
print(s.lower())
# Out:
# hello

# %%
s = 'hello'
print(s.upper())
# Out:
# HELLO

# %%
s = 'hello'
print(s.capitalize())
# Out:
# Hello

# %%
s = 'hello world'
print(s.title())
# Out:
# Hello World

# %% [markdown]
# ## Useful string methods

# %%
s = 'Sun'
print(s.isalpha())
# Out:
# True

# %%
s = 'Sun'
print(s.isdigit())
# Out:
# False

# %%
s = '123'
print(s.isdigit())
# Out:
# True

# %%
s = 'fsun123'
print(s.isalnum())
# Out:
# True
