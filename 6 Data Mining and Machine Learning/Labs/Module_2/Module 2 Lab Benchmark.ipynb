# %% [markdown]
# # Module 2 Bechmark Dataset Exploration
#
# - uses the **iris** dataset for example code
# - uses boxplot()
# - used describe()

# %%
import pandas as pd

# %%
df = pd.read_csv("D:\\Jupyter_Notebooks\\CS654ML_DM\\Data\\iris.csv")

# %%
len(df)
# Out:
# 150

# %%
df.head(10)
# Out:
#    sepalLength  sepalWidth  petalLength  petalWidth      species
# 0          5.1         3.5          1.4         0.2  Iris-setosa
# 1          4.9         3.0          1.4         0.2  Iris-setosa
# 2          4.7         3.2          1.3         0.2  Iris-setosa
# 3          4.6         3.1          1.5         0.2  Iris-setosa
# 4          5.0         3.6          1.4         0.2  Iris-setosa
# 5          5.4         3.9          1.7         0.4  Iris-setosa
# 6          4.6         3.4          1.4         0.3  Iris-setosa
# 7          5.0         3.4          1.5         0.2  Iris-setosa
# 8          4.4         2.9          1.4         0.2  Iris-setosa
# 9          4.9         3.1          1.5         0.1  Iris-setosa

# %%
#import matplotlib as plot
import matplotlib.pyplot as plt

# %%
df[['sepalLength']].boxplot()
# Out:
# <Axes: >

# %%
# use describe to get the statistics for the feature/ column

df[['sepalLength']].describe()
# Out:
#        sepalLength
# count   150.000000
# mean      5.843333
# std       0.828066
# min       4.300000
# 25%       5.100000
# 50%       5.800000
# 75%       6.400000
# max       7.900000

# %%
df.describe()
# Out:
#        sepalLength  sepalWidth  petalLength  petalWidth
# count   150.000000  150.000000   150.000000  150.000000
# mean      5.843333    3.054000     3.758667    1.198667
# std       0.828066    0.433594     1.764420    0.763161
# min       4.300000    2.000000     1.000000    0.100000
# 25%       5.100000    2.800000     1.600000    0.300000
# 50%       5.800000    3.000000     4.350000    1.300000
# 75%       6.400000    3.300000     5.100000    1.800000
# max       7.900000    4.400000     6.900000    2.500000

# %%
# boxplot of all numerical values
# Note:  need to use plot.show() to show all the boxplots

df.boxplot()
plt.show()

# %% [markdown]
# # Breast Cancer Dataset
#
# - data about breast cancer (**Note:** This CSV does not contain a header.)

# %%
# load the breast cancer dataset

df2 = pd.read_csv("D:\\Jupyter_Notebooks\\CS654ML_DM\\Data\\breast_cancer.csv", header=None)

# %%
len(df2)
# Out:
# 286

# %%
df2.columns= ['Class', 'age', 'menopause', 'tumor-size', 'inv-nodes', 'node_caps', 'deg-malig','breast', 'bread-quad', 'irradiant']

df2
# Out:
#                     Class    age menopause tumor-size inv-nodes node_caps  \
# 0    no-recurrence-events  30-39   premeno      30-34       0-2        no
# 1    no-recurrence-events  40-49   premeno      20-24       0-2        no
# 2    no-recurrence-events  40-49   premeno      20-24       0-2        no
# 3    no-recurrence-events  60-69      ge40      15-19       0-2        no
# 4    no-recurrence-events  40-49   premeno        0-4       0-2        no
# ..                    ...    ...       ...        ...       ...       ...
# 281     recurrence-events  30-39   premeno      30-34       0-2        no
# 282     recurrence-events  30-39   premeno      20-24       0-2        no
# 283     recurrence-events  60-69      ge40      20-24       0-2        no
# 284     recurrence-events  40-49      ge40      30-34       3-5        no
# 285     recurrence-events  50-59      ge40      30-34       3-5        no
#
#      deg-malig breast bread-quad irradiant
# ...

# %%
df2['deg-malig'].describe()
# Out:
# count    286.000000
# mean       2.048951
# std        0.738217
# min        1.000000
# 25%        2.000000
# 50%        2.000000
# 75%        3.000000
# max        3.000000
# Name: deg-malig, dtype: float64

# %%
df2.describe()
# Out:
#         deg-malig
# count  286.000000
# mean     2.048951
# std      0.738217
# min      1.000000
# 25%      2.000000
# 50%      2.000000
# 75%      3.000000
# max      3.000000

# %% [markdown]
# # Written digits example
#
# - uses the train.csv file

# %%
# load the written digits dataset

# df3 = pd.read_csv("D:\\Jupyter_Notebooks\\CS654ML_DM\\Data\\train.csv")

# %%
# len(df3)

# %%
# df3.head(10)

# %%
# See the image visually

import numpy as np
import matplotlib.pyplot as plot

# %%
# d = np.array(df3.iloc[0, 1:].to_list())
# d.shape = (28, 28)

# plot.imshow(255-d, cmap='gray')
# plot.show()

# %%
# type(d)

# %%
# d.shape

# %%
# d = np.array(df3.iloc[1, 1:].to_list())
# d.shape = (28, 28)

# plot.imshow(255-d, cmap='gray')
# plot.show()

# %%
# d = np.array(df3.iloc[3, 1:].to_list())
# d.shape = (28, 28)

# plot.imshow(255-d, cmap='gray')
# plot.show()

# %%
# d = np.array(df3.iloc[6, 1:].to_list())
# d.shape = (28, 28)

# plot.imshow(255-d, cmap='gray')
# plot.show()

# %%
# d = np.array(df3.iloc[7, 1:].to_list())
# d.shape = (28, 28)

# plot.imshow(255-d, cmap='gray')
# plot.show()

# %%
# d = np.array(df3.iloc[8, 1:].to_list())
# d.shape = (28, 28)

# plot.imshow(255-d, cmap='gray')
# plot.show()
