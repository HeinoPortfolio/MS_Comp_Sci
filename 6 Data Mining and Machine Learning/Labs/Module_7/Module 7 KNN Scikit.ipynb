# %% [markdown]
# # Module 7 K Nearest Neighbors Scikit-learn
#
# - KNN
# - scikit-learn

# %% [markdown]
# ### There are 20 points as training data

# %%
training_data_points = [[52, 28],[25, 95], [36, 64],[20, 94],[52, 27],[20, 96],[39, 65],[34, 90],[75, 15],
[74, 21],
[90, 43],
[60, 12],
[67, 20],
[30, 92],
[61, 31],
[8, 74],
[51, 32],
[64, 41], [15, 80], [9, 80]]

# %% [markdown]
# ### Class labels associated with training data

# %%
training_data_labels=['A','A','A','A','A','A','A','A','A','A','B','B','B','B','B','B','B','B','B','B']

# %%
len(training_data_labels)
# Out:
# 20

# %%
len(training_data_points)
# Out:
# 20

# %% [markdown]
# ### Load the KNN classifier in scikit-learn

# %%
from sklearn.neighbors import KNeighborsClassifier

# %% [markdown]
# ### Use 1NN
#
# - using one (1) nearest neighbors

# %%
neigh = KNeighborsClassifier(n_neighbors=1)

# %% [markdown]
# ### Learning: create the classifier
#
# - creation of the classifier

# %%
neigh.fit(training_data_points, training_data_labels)
# Out:
# KNeighborsClassifier(n_neighbors=1)

# %% [markdown]
# ### Predict the class label of a new point (10, 80)

# %%
neigh.predict([[10, 80]])
# Out:
# array(['B'], dtype='<U1')

# %% [markdown]
# ### Predict the training data with 1 neightbor; perfect match! Why?

# %%
neigh.predict(training_data_points)
# Out:
# array(['A', 'A', 'A', 'A', 'A', 'A', 'A', 'A', 'A', 'A', 'B', 'B', 'B',
#        'B', 'B', 'B', 'B', 'B', 'B', 'B'], dtype='<U1')

# %% [markdown]
# ### We got 10 points for testing.

# %%
test_data_points = [[41, 60], [25, 6], [99, 21], [44,44], [32, 33],[32, 57], [10, 56], [88,88], [3, 4], [60, 23]]

# %% [markdown]
# ### True labels of the test data; only used for accuracy evaluation

# %%
test_data_labels = ['A','A','A','A','A','B','B','B','B','B']

# %% [markdown]
# ### Use 1NN

# %%
knn_classifier_1 = KNeighborsClassifier(n_neighbors=1)

knn_classifier_1.fit(training_data_points, training_data_labels)
# Out:
# KNeighborsClassifier(n_neighbors=1)

# %% [markdown]
# ### Make predictions for test data

# %%
knn_classifier_1.predict(test_data_points)
# Out:
# array(['A', 'A', 'B', 'B', 'B', 'A', 'B', 'B', 'A', 'B'], dtype='<U1')

# %% [markdown]
# ### Store the predictions in a list

# %%
knn_1_predictions = list(knn_classifier_1.predict(test_data_points))

# %% [markdown]
# ### Find out how many errors in my predictions; predictions against true labels

# %%
error_of_A = 0
error_of_B = 0

for i in range(int(len(test_data_labels)*0.5)):
    if knn_1_predictions[i] != test_data_labels[i]:
        error_of_A = error_of_A + 1

for i in range(int(len(test_data_labels)*0.5), len(test_data_labels)):
    if knn_1_predictions[i] != test_data_labels[i]:
        error_of_B = error_of_B + 1

# %%
print(error_of_A/5) # since we made 3 errors (Bs)
print(error_of_B/5) # since we made 2 errors (As)
# Out:
# 0.6
# 0.4
