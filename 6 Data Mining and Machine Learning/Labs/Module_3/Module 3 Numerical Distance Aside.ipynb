# %% [markdown]
# # Module 3 Distances of Numerical Data
#
# - calculate the distance between different rows

# %% [markdown]
# # Distance computation for numerical values

# %%
# assign ten integersto list l.

l = [29, 27, 15, 27, 24, 17, 35, 18, 11, 24]

# %%
import copy

# %%
# create a deep copy of l, and assign it to k.
k = copy.deepcopy(l)

# %%
# sort k list.
k.sort()

# %%
# verify k.
print(k)
# Out:
# [11, 15, 17, 18, 24, 24, 27, 27, 29, 35]

# %%
# assign the min value of k as min_v, and the max value of k as max_v.
min_v = k[0]
max_v = k[-1]

# verify the min and max values.
print(min_v)
print(max_v)
# Out:
# 11
# 35

# %%
# l is not changed. 
print(l)
# Out:
# [29, 27, 15, 27, 24, 17, 35, 18, 11, 24]

# %% [markdown]
# ## Normalize the values in l into range [0..1]

# %%
l_nor = []

for x in l:
    print(round((x-min_v)/(max_v - min_v), 2))
    l_nor.append(round((x-min_v)/(max_v - min_v), 2))
# Out:
# 0.75
# 0.67
# 0.17
# 0.67
# 0.54
# 0.25
# 1.0
# 0.29
# 0.0
# 0.54

# %%
# verify l_nor.
print(l_nor)
# Out:
# [0.75, 0.67, 0.17, 0.67, 0.54, 0.25, 1.0, 0.29, 0.0, 0.54]

# %%
# contrast to values in l.
print(l)
# Out:
# [29, 27, 15, 27, 24, 17, 35, 18, 11, 24]

# %%
# create empty distance_matrix and distace_row.

distance_matrix = []
distance_row = []

# %% [markdown]
# ## Compute the distance_matrix.

# %%
import math

distance_matrix = []

for i in range(len(l_nor)):
    
    distance_row = []
    
    for j in range(len(l_nor)):
        #print(str(i) + ", " + str(j))
        print(round(math.fabs(l_nor[i] - l_nor[j]), 2), end="\t")
        distance_row.append(round(math.fabs(l_nor[i] - l_nor[j]), 2))
    print("\n")
    
    distance_matrix.append(distance_row)
# Out:
# 0.0	0.08	0.58	0.08	0.21	0.5	0.25	0.46	0.75	0.21
#
# 0.08	0.0	0.5	0.0	0.13	0.42	0.33	0.38	0.67	0.13
#
# 0.58	0.5	0.0	0.5	0.37	0.08	0.83	0.12	0.17	0.37
#
# 0.08	0.0	0.5	0.0	0.13	0.42	0.33	0.38	0.67	0.13
#
# 0.21	0.13	0.37	0.13	0.0	0.29	0.46	0.25	0.54	0.0
#
# 0.5	0.42	0.08	0.42	0.29	0.0	0.75	0.04	0.25	0.29
#
# 0.25	0.33	0.83	0.33	0.46	0.75	0.0	0.71	1.0	0.46
#
# 0.46	0.38	0.12	0.38	0.25	0.04	0.71	0.0	0.29	0.25
#
# 0.75	0.67	0.17	0.67	0.54	0.25	1.0	0.29	0.0	0.54
#
# 0.21	0.13	0.37	0.13	0.0	0.29	0.46	0.25	0.54	0.0

# %% [markdown]
# ## Since the matrix is symmetric, thus only need to compute the half of it.

# %%
import math

for i in range(len(l_nor)):
    for j in range(len(l_nor)):
        #print(str(i) + ", " + str(j))
        if (j>=i):
            print(round(math.fabs(l_nor[i] - l_nor[j]), 2), end="\t")
        else:
            print("", end = "\t")
    
    print()
# Out:
# 0.0	0.08	0.58	0.08	0.21	0.5	0.25	0.46	0.75	0.21
# 	0.0	0.5	0.0	0.13	0.42	0.33	0.38	0.67	0.13
# 		0.0	0.5	0.37	0.08	0.83	0.12	0.17	0.37
# 			0.0	0.13	0.42	0.33	0.38	0.67	0.13
# 				0.0	0.29	0.46	0.25	0.54	0.0
# 					0.0	0.75	0.04	0.25	0.29
# 						0.0	0.71	1.0	0.46
# 							0.0	0.29	0.25
# 								0.0	0.54
# 									0.0

# %%
# verify the distance matrix.

print(distance_matrix)
# Out:
# [[0.0, 0.08, 0.58, 0.08, 0.21, 0.5, 0.25, 0.46, 0.75, 0.21], [0.08, 0.0, 0.5, 0.0, 0.13, 0.42, 0.33, 0.38, 0.67, 0.13], [0.58, 0.5, 0.0, 0.5, 0.37, 0.08, 0.83, 0.12, 0.17, 0.37], [0.08, 0.0, 0.5, 0.0, 0.13, 0.42, 0.33, 0.38, 0.67, 0.13], [0.21, 0.13, 0.37, 0.13, 0.0, 0.29, 0.46, 0.25, 0.54, 0.0], [0.5, 0.42, 0.08, 0.42, 0.29, 0.0, 0.75, 0.04, 0.25, 0.29], [0.25, 0.33, 0.83, 0.33, 0.46, 0.75, 0.0, 0.71, 1.0, 0.46], [0.46, 0.38, 0.12, 0.38, 0.25, 0.04, 0.71, 0.0, 0.29, 0.25], [0.75, 0.67, 0.17, 0.67, 0.54, 0.25, 1.0, 0.29, 0.0, 0.54], [0.21, 0.13, 0.37, 0.13, 0.0, 0.29, 0.46, 0.25, 0.54, 0.0]]

# %% [markdown]
# ## Similarity matrix = 1 - distance matrix

# %%
similarity_matrix = []

for i in range(len(l_nor)):
    similarity_row = []
    for j in range(len(l_nor)):
        similarity_row.append(round(1- distance_matrix[i][j], 2))
    #print("\n")
    similarity_matrix.append(similarity_row)

# %%
# verify the similary matrix

print(similarity_matrix)
# Out:
# [[1.0, 0.92, 0.42, 0.92, 0.79, 0.5, 0.75, 0.54, 0.25, 0.79], [0.92, 1.0, 0.5, 1.0, 0.87, 0.58, 0.67, 0.62, 0.33, 0.87], [0.42, 0.5, 1.0, 0.5, 0.63, 0.92, 0.17, 0.88, 0.83, 0.63], [0.92, 1.0, 0.5, 1.0, 0.87, 0.58, 0.67, 0.62, 0.33, 0.87], [0.79, 0.87, 0.63, 0.87, 1.0, 0.71, 0.54, 0.75, 0.46, 1.0], [0.5, 0.58, 0.92, 0.58, 0.71, 1.0, 0.25, 0.96, 0.75, 0.71], [0.75, 0.67, 0.17, 0.67, 0.54, 0.25, 1.0, 0.29, 0.0, 0.54], [0.54, 0.62, 0.88, 0.62, 0.75, 0.96, 0.29, 1.0, 0.71, 0.75], [0.25, 0.33, 0.83, 0.33, 0.46, 0.75, 0.0, 0.71, 1.0, 0.46], [0.79, 0.87, 0.63, 0.87, 1.0, 0.71, 0.54, 0.75, 0.46, 1.0]]
