# %% [markdown]
# CS 621 Foundation of Data Analytics
# Module 6
#
# Author:  Matthew Heino

# %%
import pandas as pd
import matplotlib.pyplot as plt

pd.set_option('display.max_rows', 150)

# %%
# Read in the file.

df = pd.read_excel('iris.xlsx')
df2 = pd.read_csv('iris.csv')

# %% [markdown]
# # Question 1
#
# What is the smallest numerical value in this dataset?

# %%
# Find the smallest value in the dataframe

min_values = df.min()
print("\nQuestion 1:\nThe smallest value in the dataframe:\n\n", min_values)

min_values2 = df2.min()
print("\nQuestion 1:\nThe smallest value in the dataframe:\n\n", min_values2)
# Out:
# Question 1:
# The smallest value in the dataframe:
#
#  sepalLength            4.3
# sepalWidth             2.0
# petalLength            1.0
# petalWidth             0.1
# species        Iris-setosa
# dtype: object
#
# Question 1:
# The smallest value in the dataframe:
#
#  sepalLength            4.3
# sepalWidth             2.0
# petalLength            1.0
# petalWidth             0.1
# species        Iris-setosa
# dtype: object

# %% [markdown]
# # Question 2
#
# What is the largest numerical value in this dataset?

# %%
max_values = df.max()
print("\n\nQuestion 2:\n\nThe largest numerical value in this dataset: \n\n",max_values)

max_values2 = df2.max()
print("\nQuestion 2:\n\nThe largest numerical value in this dataset: \n\n",max_values2)
# Out:
# Question 2:
#
# The largest numerical value in this dataset:
#
#  sepalLength               7.9
# sepalWidth                4.4
# petalLength               6.9
# petalWidth                2.5
# species        Iris-virginica
# dtype: object
#
# Question 2:
#
# The largest numerical value in this dataset:
#
#  sepalLength               7.9
# sepalWidth                4.4
# petalLength               6.9
# petalWidth                2.5
# species        Iris-virginica
# dtype: object

# %% [markdown]
# # Question 3
#
# Check for duplicated rows

# %%
#df1_dups = df.duplicated()

print("Dataframe 1:\n",df.duplicated())

#print("Dataframe 2:",df2.duplicated())
# Out:
# Dataframe 1:
#  0      False
# 1      False
# 2      False
# 3      False
# 4      False
# 5      False
# 6      False
# 7      False
# 8      False
# 9      False
# 10     False
# 11     False
# 12     False
# 13     False
# 14     False
# 15     False
# 16     False
# 17     False
# 18     False
# 19     False
# 20     False
# 21     False
# 22     False
# 23     False
# 24     False
# 25     False
# 26     False
# 27     False
# 28     False
# 29     False
# 30     False
# 31     False
# 32     False
# 33     False
# 34      True
# 35     False
# 36     False
# 37      True
# 38     False
# 39     False
# 40     False
# 41     False
# 42     False
# 43     False
# 44     False
# 45     False
# 46     False
# 47     False
# 48     False
# 49     False
# 50     False
# 51     False
# 52     False
# 53     False
# 54     False
# 55     False
# 56     False
# 57     False
# 58     False
# 59     False
# 60     False
# 61     False
# 62     False
# 63     False
# 64     False
# 65     False
# 66     False
# 67     False
# 68     False
# 69     False
# 70     False
# 71     False
# 72     False
# 73     False
# 74     False
# 75     False
# 76     False
# 77     False
# 78     False
# 79     False
# 80     False
# 81     False
# 82     False
# 83     False
# 84     False
# 85     False
# 86     False
# 87     False
# 88     False
# 89     False
# 90     False
# 91     False
# 92     False
# 93     False
# 94     False
# 95     False
# 96     False
# 97     False
# 98     False
# 99     False
# 100    False
# 101    False
# 102    False
# 103    False
# 104    False
# 105    False
# 106    False
# 107    False
# 108    False
# 109    False
# 110    False
# 111    False
# 112    False
# 113    False
# 114    False
# 115    False
# 116    False
# 117    False
# 118    False
# 119    False
# 120    False
# 121    False
# 122    False
# 123    False
# 124    False
# 125    False
# 126    False
# 127    False
# 128    False
# 129    False
# 130    False
# 131    False
# 132    False
# 133    False
# 134    False
# 135    False
# 136    False
# 137    False
# 138    False
# 139    False
# 140    False
# 141    False
# 142     True
# 143    False
# 144    False
# 145    False
# 146    False
# 147    False
# 148    False
# 149    False
# dtype: bool

# %% [markdown]
# # Question 4
#
# What is the mean value of sepalLength?

# %%
print("\nQuestion 4: ",df['sepalLength'].mean())
# Out:
# Question 4:  5.843333333333334

# %% [markdown]
# # Question 5
#
# What is the standard deviation value of sepalLenth?

# %%
print("\nQuestion 5:\nStandard deviation value of sepalLenth: ",df['sepalLength'].std())
print("\nQuestion 5: \nStandard deviation value of sepalLenth: ", df2['sepalLength'].std())
# Out:
# Question 5:
# Standard deviation value of sepalLenth:  0.8280661279778629
#
# Question 5:
# Standard deviation value of sepalLenth:  0.8280661279778629

# %% [markdown]
# # Question 6
#
# Which column has outliers shown on its boxplot?

# %%
# Draw a boxplot
df.boxplot()
# Out:
# <Axes: >

# %% [markdown]
# # Question 7
#
# Draw a box plot of sepalLenth column

# %%
#df.boxplot(column='sepalLength')
#plt.show()  # new line

# save the file
sepalLength_img = df['sepalLength'].plot(kind='box', figsize=(20, 20)
                                         , fontsize=26, title='Sepal Length').get_figure()
plt.show()

sepalLength_img.savefig('box_sepalLength.pdf')

# %% [markdown]
# # Question 8
#
# Draw a scatter plot of columns sepalLength and pedalLength.

# %%
scatter_img = df.plot(kind='scatter',figsize=(15, 15), fontsize=20
                      , x='sepalLength',y='petalLength', title=" Petal Length vs Sepal Length ").get_figure()
plt.show()

scatter_img.savefig('scatter.pdf')

# %% [markdown]
# # Question 9
#
# Draw a histogram of column sepalWidth using 20 bins

# %%
hist_img = df['sepalWidth'].plot.hist(bins=20, title='Histogram of Sepal Width', figsize=(10, 10), fontsize=20, legend=True
                                      , xlabel= 'Sepal Width').get_figure()
plt.show()

hist_img.savefig('hist.pdf')
